# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#nltk
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

#sklearn
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import ConfusionMatrixDisplay

#sklearn models
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier, RandomForestClassifier

#train test split
from sklearn.model_selection import train_test_split

#re
import re

# %% [markdown]
# # Setting Variables

# %%
RANDOM_STATE = 1
np.random.seed(RANDOM_STATE)

# %% [markdown]
# # Loading Data

# %%
vc = pd.read_excel('Vintage Consumption.xlsx')

# %% [markdown]
# # Data Preparation

# %%
pd.set_option('display.max_columns', None)
vc.head()
# Out:
#              StartDate              EndDate         Status       IPAddress  \
# 0           Start Date             End Date  Response Type      IP Address
# 1  2021-11-16 09:26:41  2021-11-16 09:30:38              0   37.119.23.253
# 2  2021-11-16 09:26:24  2021-11-16 09:31:00              0  109.51.252.232
# 3  2021-11-16 09:26:47  2021-11-16 09:31:01              0    77.54.67.238
# 4  2021-11-16 09:28:00  2021-11-16 09:31:03              0    89.154.40.40
#
#    Progress  Duration (in seconds)  Finished                RecordedDate  \
# 0  Progress  Duration (in seconds)  Finished               Recorded Date
# 1       100                    236         1  2021-11-16 09:30:38.675000
# 2       100                    275         1  2021-11-16 09:31:00.720000
# 3       100                    253         1  2021-11-16 09:31:01.698000
# 4       100                    183         1  2021-11-16 09:31:04.012000
#
#           ResponseId    RecipientLastName    RecipientFirstName  \
# 0        Response ID  Recipient Last Name  Recipient First Name
# 1  R_3VJFZHFXifLWPyF                  NaN                   NaN
# 2  R_2vZEGaXnPCmdGbi                  NaN                   NaN
# 3  R_1LCATrXRVAXliBZ                  NaN                   NaN
# 4  R_2alZoFgLkCqkKC7                  NaN                   NaN
#
#     RecipientEmail        ExternalReference   LocationLatitude  \
# 0  Recipient Email  External Data Reference  Location Latitude
# 1              NaN                      NaN            45.0914
# 2              NaN                      NaN          38.962799
# 3              NaN                      NaN          40.926605
# 4              NaN                      NaN          41.380005
#
#     LocationLongitude   DistributionChannel   UserLanguage  \
# 0  Location Longitude  Distribution Channel  User Language
# 1            7.663895             anonymous             EN
# 2           -9.420807             anonymous             EN
# 3           -8.545807             anonymous             EN
# 4           -8.770996             anonymous             EN
#
#                                              consent  \
# 0  Dear participant,\n\nThis is a study about con...
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                           ProlificID  \
# 0  What is your Prolific ID? \nPlease note that t...
# 1                           5e82332d4fa0db0b3df909ff
# 2                           5fc26d71c9e79a327ac24f7f
# 3                           5f53bd22e52c096e869c985e
# 4                           5f89a35824bee7076b6d536c
#
#                              scarcity_6  \
# 0  Adapted from Roux et al. (2015) - 1.
# 1                                   NaN
# 2                                   NaN
# 3     When I had to do work for school.
# 4                                   NaN
#
#                                     scarcity_9  \
# 0         Adapted from Roux et al. (2015) - 2.
# 1                                          NaN
# 2                                          NaN
# 3  When I had to cook for a big party at home.
# 4                                          NaN
#
#                              scarcity_7 timing.IV_First Click  \
# 0  Adapted from Roux et al. (2015) - 3.  Timing - First Click
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3   When I had to run to catch the bus.                20.546
# 4                                   NaN                   NaN
#
#   timing.IV_Last Click timing.IV_Page Submit timing.IV_Click Count  \
# 0  Timing - Last Click  Timing - Page Submit  Timing - Click Count
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
# 3               73.944                75.663                     8
# 4                  NaN                   NaN                   NaN
#
#                  control_1                control_2                control_3  \
# 0  Roux et al. (2015) - 1.  Roux et al. (2015) - 2.  Roux et al. (2015) - 3.
# 1                 shopping                   school                    party
# 2                    study                    party                     rest
# 3                      NaN                      NaN                      NaN
# 4           went to school                  studied               programmed
#
#   timing.IV.control_First Click timing.IV.control_Last Click  \
# 0          Timing - First Click          Timing - Last Click
# 1                         5.869                       14.245
# 2                         2.262                        2.262
# 3                           NaN                          NaN
# 4                         1.672                        2.079
#
#   timing.IV.control_Page Submit timing.IV.control_Click Count  \
# 0          Timing - Page Submit          Timing - Click Count
# 1                        30.579                             3
# 2                        20.884                             1
# 3                           NaN                           NaN
# 4                        12.938                             2
#
#                                            JacketM_1  \
# 0  Brand New Leather Jacket \n\n\n\nTan backgroun...
# 1                                                NaN
# 2                                                  1
# 3                                                NaN
# 4                                                  2
#
#                                            JacketM_2  \
# 0  Brand New Leather Jacket \n\n\n\nTan backgroun...
# 1                                                NaN
# 2                                                  5
# 3                                                NaN
# 4                                                  2
#
#                                            JacketM_3  \
# 0  Brand New Leather Jacket \n\n\n\nTan backgroun...
# 1                                                NaN
# 2                                                  9
# 3                                                NaN
# 4                                                  8
#
#                                           ScooterM_1  \
# 0  Brand New Model Scooter\n\n \n\nSPECIFICATIONS...
# 1                                                NaN
# 2                                                  1
# 3                                                NaN
# 4                                                  2
#
#                                           ScooterM_2  \
# 0  Brand New Model Scooter\n\n \n\nSPECIFICATIONS...
# 1                                                NaN
# 2                                                  9
# 3                                                NaN
# 4                                                  2
#
#                                           ScooterM_3  \
# 0  Brand New Model Scooter\n\n \n\nSPECIFICATIONS...
# 1                                                NaN
# 2                                                  9
# 3                                                NaN
# 4                                                  8
#
#                                             WatchM_1  \
# 0  Imagine yourself wearing this $550 Modern watc...
# 1                                                NaN
# 2                                                  6
# 3                                                NaN
# 4                                                  4
#
#                                             WatchM_2  \
# 0  Imagine yourself wearing this $550 Modern watc...
# 1                                                NaN
# 2                                                  1
# 3                                                NaN
# 4                                                  2
#
#                                             WatchM_3  \
# 0  Imagine yourself wearing this $550 Modern watc...
# 1                                                NaN
# 2                                                  9
# 3                                                NaN
# 4                                                  8
#
#                                            JacketV_1  \
# 0  Vintage Leather Jacket from 1970s\n\n\n\nTan b...
# 1                                                  5
# 2                                                NaN
# 3                                                  4
# 4                                                NaN
#
#                                            JacketV_2  \
# 0  Vintage Leather Jacket from 1970s\n\n\n\nTan b...
# 1                                                  5
# 2                                                NaN
# 3                                                  1
# 4                                                NaN
#
#                                            JacketV_3  \
# 0  Vintage Leather Jacket from 1970s\n\n\n\nTan b...
# 1                                                  5
# 2                                                NaN
# 3                                                  7
# 4                                                NaN
#
#                                           ScooterV_1  \
# 0  Vintage Scooter from 1975\n\n \n\nSPECIFICATIO...
# 1                                                  7
# 2                                                NaN
# 3                                                  7
# 4                                                NaN
#
#                                           ScooterV_2  \
# 0  Vintage Scooter from 1975\n\n \n\nSPECIFICATIO...
# 1                                                  5
# 2                                                NaN
# 3                                                  6
# 4                                                NaN
#
#                                           ScooterV_3  \
# 0  Vintage Scooter from 1975\n\n \n\nSPECIFICATIO...
# 1                                                  5
# 2                                                NaN
# 3                                                  6
# 4                                                NaN
#
#                                             WatchV_1  \
# 0  Imagine yourself wearing this $550 Vintage wat...
# 1                                                  3
# 2                                                NaN
# 3                                                  2
# 4                                                NaN
#
#                                             WatchV_2  \
# 0  Imagine yourself wearing this $550 Vintage wat...
# 1                                                  3
# 2                                                NaN
# 3                                                  2
# 4                                                NaN
#
#                                             WatchV_3  \
# 0  Imagine yourself wearing this $550 Vintage wat...
# 1                                                  5
# 2                                                NaN
# 3                                                  5
# 4                                                NaN
#
#                                          Nostalgia_1  \
# 0  Sarial-Abi et al. (2017) - I feel nostalgic at...
# 1                                                  2
# 2                                                  1
# 3                                                  4
# 4                                                  1
#
#                                          Nostalgia_2  \
# 0  Sarial-Abi et al. (2017) - Right now I am havi...
# 1                                                  4
# 2                                                  1
# 3                                                  4
# 4                                                  1
#
#                 Intertemp.connection_1  \
# 0  Sarial-Abi et al. (2017) - The past
# 1                                    8
# 2                                    5
# 3                                    9
# 4                                    7
#
#                    Intertemp.connection_2  \
# 0  Sarial-Abi et al. (2017) - The present
# 1                                       8
# 2                                       5
# 3                                       5
# 4                                       4
#
#                   Intertemp.connection_3  \
# 0  Sarial-Abi et al. (2017) - The future
# 1                                      5
# 2                                      5
# 3                                      8
# 4                                      7
#
#                               Intertemp.connection_4  \
# 0  Sarial-Abi et al. (2017) - The past in relatio...
# 1                                                  6
# 2                                                  6
# 3                                                  6
# 4                                                  3
#
#                               Intertemp.connection_5  \
# 0  Sarial-Abi et al. (2017) - The past in relatio...
# 1                                                  4
# 2                                                  7
# 3                                                  7
# 4                                                  8
#
#                               Intertemp.connection_6  \
# 0  Sarial-Abi et al. (2017) - The present in rela...
# 1                                                  6
# 2                                                  6
# 3                                                  7
# 4                                                  8
#
#                               Intertemp.connection_7  \
# 0  Sarial-Abi et al. (2017) - The past in relatio...
# 1                                                  8
# 2                                                  7
# 3                                                  6
# 4                                                  4
#
#                                 Future Orientation_1  \
# 0  Wang & Chao (2019) - Thinking about the future...
# 1                                                  4
# 2                                                  5
# 3                                                  8
# 4                                                  4
#
#                                 Future Orientation_2  \
# 0  Wang & Chao (2019) - When I want to achieve so...
# 1                                                  6
# 2                                                  4
# 3                                                  6
# 4                                                  8
#
#                                 Future Orientation_3  \
# 0  Wang & Chao (2019) - Meeting tomorrow's deadli...
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  8
#
#                                 Future Orientation_4  \
# 0  Wang & Chao (2019) - It seems to me that my fu...
# 1                                                  9
# 2                                                  3
# 3                                                  6
# 4                                                  6
#
#                                        manip_check_1  \
# 0  Adapted from Roux et al. (2015) - Right now, I...
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                  3
#
#                                        manip_check_2  \
# 0  Adapted from Roux et al. (2015) - Right now, I...
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                  4
#
#                                        manip_check_3  \
# 0  Adapted from Roux et al. (2015) - Right now, I...
# 1                                                  6
# 2                                                  6
# 3                                                  8
# 4                                                  5
#
#                                        manip_check_4  \
# 0  Adapted from Roux et al. (2015) - Right now, I...
# 1                                                  8
# 2                                                  1
# 3                                                  8
# 4                                                  6
#
#                                    meaning in life_1  \
# 0  Steger et al. (2006) - I understand my life’s ...
# 1                                                  7
# 2                                                  6
# 3                                                  3
# 4                                                  7
#
#                                    meaning in life_2  \
# 0  Steger et al. (2006) - I am looking for someth...
# 1                                                  8
# 2                                                  4
# 3                                                  7
# 4                                                  4
#
#                                    meaning in life_3  \
# 0  Steger et al. (2006) - I am always looking to ...
# 1                                                  7
# 2                                                  3
# 3                                                  6
# 4                                                  2
#
#                                    meaning in life_4  \
# 0  Steger et al. (2006) - My life has a clear sen...
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                  3
#
#                                    meaning in life_5  \
# 0  Steger et al. (2006) - I have a good sense of ...
# 1                                                  6
# 2                                                  6
# 3                                                  7
# 4                                                  4
#
#                                    meaning in life_6  \
# 0  Steger et al. (2006) - I have discovered a sat...
# 1                                                  8
# 2                                                  2
# 3                                                  7
# 4                                                  5
#
#                                    meaning in life_7  \
# 0  Steger et al. (2006) - I am always searching f...
# 1                                                  7
# 2                                                  4
# 3                                                  7
# 4                                                  7
#
#                                    meaning in life_8  \
# 0  Steger et al. (2006) - I am seeking a purpose ...
# 1                                                  7
# 2                                                  5
# 3                                                  6
# 4                                                  6
#
#                                    meaning in life_9  \
# 0  Steger et al. (2006) - My life has no clear pu...
# 1                                                  6
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#                                   meaning in life_10  \
# 0  Steger et al. (2006) - I am searching for mean...
# 1                                                  6
# 2                                                  2
# 3                                                  6
# 4                                                  2
#
#                                   meaning in life_11  \
# 0  Steger et al. (2006) - I think ice tea is over...
# 1                                                  6
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#                                need for uniqueness_1  \
# 0  Ruvio, Shoham, - I often combine possessions i...
# 1                                                 11
# 2                                                  5
# 3                                                 11
# 4                                                  4
#
#                                need for uniqueness_2  \
# 0  Ruvio, Shoham, - I often try to find a more in...
# 1                                                  7
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                need for uniqueness_3  \
# 0  Ruvio, Shoham, - I actively seek to develop my...
# 1                                                 11
# 2                                                  7
# 3                                                  7
# 4                                                  4
#
#                                need for uniqueness_4  \
# 0  Ruvio, Shoham, - Having an eye for products th...
# 1                                                 11
# 2                                                  7
# 3                                                  5
# 4                                                  7
#
#                                need for uniqueness_5  \
# 0  Ruvio, Shoham, - When it comes to the products...
# 1                                                  7
# 2                                                  3
# 3                                                 11
# 4                                                  4
#
#                                need for uniqueness_6  \
# 0  Ruvio, Shoham, - I have often violated the und...
# 1                                                 11
# 2                                                  5
# 3                                                  6
# 4                                                  4
#
#                                need for uniqueness_7  \
# 0  Ruvio, Shoham, - I have often gone against the...
# 1                                                 11
# 2                                                  5
# 3                                                  5
# 4                                                  7
#
#                                need for uniqueness_8  \
# 0  Ruvio, Shoham, - I enjoy challenging the preva...
# 1                                                 11
# 2                                                  7
# 3                                                  7
# 4                                                  4
#
#                                need for uniqueness_9  \
# 0  Ruvio, Shoham, - When a product I own becomes ...
# 1                                                  7
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#                               need for uniqueness_10  \
# 0  Ruvio, Shoham, - I often try to avoid products...
# 1                                                 11
# 2                                                  4
# 3                                                  6
# 4                                                  6
#
#                               need for uniqueness_11  \
# 0  Ruvio, Shoham, - As a rule, I dislike products...
# 1                                                 12
# 2                                                  3
# 3                                                  6
# 4                                                  3
#
#                               need for uniqueness_12  \
# 0  Ruvio, Shoham, - The more commonplace a produc...
# 1                                                 11
# 2                                                  3
# 3                                                  5
# 4                                                  5
#
#                                     Sustainability_1  \
# 0  Adapted from Guzzetti et al. (2021) - Buying v...
# 1                                                 10
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                     Sustainability_2  \
# 0  Adapted from Guzzetti et al. (2021) - The purc...
# 1                                                 10
# 2                                                  3
# 3                                                  4
# 4                                                  7
#
#                                Fresh Start Mindset_1  \
# 0  Price et al. (2018) - Regardless of present ci...
# 1                                                  8
# 2                                                  6
# 3                                                  6
# 4                                                  3
#
#                                Fresh Start Mindset_2  \
# 0  Price et al. (2018) - Anyone can make a new st...
# 1                                                  6
# 2                                                  5
# 3                                                  5
# 4                                                  7
#
#                                Fresh Start Mindset_3  \
# 0  Price et al. (2018) - It’s always possible for...
# 1                                                  6
# 2                                                  5
# 3                                                  7
# 4                                                  5
#
#                                Fresh Start Mindset_4  \
# 0  Price et al. (2018) - Whatever their past, peo...
# 1                                                  7
# 2                                                  5
# 3                                                  6
# 4                                                  3
#
#                                Fresh Start Mindset_5  \
# 0  Price et al. (2018) - An individual can let go...
# 1                                                  7
# 2                                                  8
# 3                                                  4
# 4                                                  6
#
#                                Fresh Start Mindset_6  \
# 0  Price et al. (2018) - When something bad happe...
# 1                                                  9
# 2                                                  5
# 3                                                  5
# 4                                                  7
#
#                                Fresh Start Mindset_7  \
# 0  Price et al. (2018) - It's impossible for a pe...
# 1                                                  8
# 2                                                  3
# 3                                                  5
# 4                                                  5
#
#                                Fresh Start Mindset_8  \
# 0  Price et al. (2018) - No matter how much someo...
# 1                                                  8
# 2                                                  6
# 3                                                  6
# 4                                                  5
#
#                                Fresh Start Mindset_9  \
# 0  Price et al. (2018) - People have to live with...
# 1                                                  8
# 2                                                  3
# 3                                                  7
# 4                                                  7
#
#                               Fresh Start Mindset_10  \
# 0  Price et al. (2018) - Every morning, people ha...
# 1                                                  7
# 2                                                  5
# 3                                                  6
# 4                                                  7
#
#                               Fresh Start Mindset_11  \
# 0  Price et al. (2018) - People can’t escape thei...
# 1                                                  7
# 2                                                  3
# 3                                                  7
# 4                                                  5
#
#                               Fresh Start Mindset_12  \
# 0  Price et al. (2018) - A mistake in the past wi...
# 1                                                  7
# 2                                                  7
# 3                                                  5
# 4                                                  5
#
#                               Fresh Start Mindset_13  \
# 0  Price et al. (2018) - A person's life today de...
# 1                                                  7
# 2                                                  4
# 3                                                  6
# 4                                                  7
#
#                               Fresh Start Mindset_14  \
# 0  Price et al. (2018) - People can change their ...
# 1                                                  7
# 2                                                  4
# 3                                                  6
# 4                                                  6
#
#                                      BIS/BAS scale_1  \
# 0  Carver & White (1994) - A person's family is t...
# 1                                                  9
# 2                                                  6
# 3                                                  5
# 4                                                  7
#
#                                      BIS/BAS scale_2  \
# 0  Carver & White (1994) - Even if something bad ...
# 1                                                  8
# 2                                                  5
# 3                                                  5
# 4                                                  6
#
#                                      BIS/BAS scale_3  \
# 0  Carver & White (1994) - I go out of my way to ...
# 1                                                  7
# 2                                                  4
# 3                                                  6
# 4                                                  7
#
#                                      BIS/BAS scale_4  \
# 0  Carver & White (1994) - When I am doing well a...
# 1                                                  6
# 2                                                  6
# 3                                                  7
# 4                                                  6
#
#                                      BIS/BAS scale_5  \
# 0  Carver & White (1994) - I am always willing to...
# 1                                                  6
# 2                                                  5
# 3                                                  7
# 4                                                  6
#
#                                      BIS/BAS scale_6  \
# 0  Carver & White (1994) - How I dress is importa...
# 1                                                  6
# 2                                                  4
# 3                                                  5
# 4                                                  6
#
#                                      BIS/BAS scale_7  \
# 0  Carver & White (1994) - When I get something I...
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  6
#
#                                      BIS/BAS scale_8  \
# 0  Carver & White (1994) - Criticism or scolding ...
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                  6
#
#                                      BIS/BAS scale_9  \
# 0  Carver & White (1994) - When I want something ...
# 1                                                  8
# 2                                                  3
# 3                                                  5
# 4                                                  7
#
#                                     BIS/BAS scale_10  \
# 0  Carver & White (1994) - I will often do things...
# 1                                                  6
# 2                                                  7
# 3                                                  4
# 4                                                  6
#
#                                     BIS/BAS scale_11  \
# 0  Carver & White (1994) - It is hard for me to f...
# 1                                                  7
# 2                                                  1
# 3                                                  4
# 4                                                  8
#
#                                     BIS/BAS scale_12  \
# 0  Carver & White (1994) - If I see a chance to g...
# 1                                                  8
# 2                                                  9
# 3                                                  4
# 4                                                  8
#
#                                     BIS/BAS scale_13  \
# 0  Carver & White (1994) - I feel pretty worried ...
# 1                                                  8
# 2                                                  5
# 3                                                  5
# 4                                                  7
#
#                                     BIS/BAS scale_14  \
# 0  Carver & White (1994) - When I see an opportun...
# 1                                                  8
# 2                                                  2
# 3                                                  5
# 4                                                  7
#
#                                     BIS/BAS scale_15  \
# 0  Carver & White (1994) - I often act on the spu...
# 1                                                  7
# 2                                                  8
# 3                                                  3
# 4                                                  6
#
#                                     BIS/BAS scale_16  \
# 0  Carver & White (1994) - If I think something u...
# 1                                                  7
# 2                                                  5
# 3                                                  5
# 4                                                  7
#
#                                     BIS/BAS scale_17  \
# 0  Carver & White (1994) - I often wonder why peo...
# 1                                                  7
# 2                                                  3
# 3                                                  4
# 4                                                  7
#
#                                     BIS/BAS scale_18  \
# 0  Carver & White (1994) - When good things happe...
# 1                                                  7
# 2                                                  3
# 3                                                  4
# 4                                                  7
#
#                                     BIS/BAS scale_19  \
# 0  Carver & White (1994) - I feel worried when I ...
# 1                                                  7
# 2                                                  7
# 3                                                  6
# 4                                                  8
#
#                                     BIS/BAS scale_20  \
# 0  Carver & White (1994) - I crave excitement and...
# 1                                                  7
# 2                                                  4
# 3                                                  3
# 4                                                  6
#
#                                     BIS/BAS scale_21  \
# 0  Carver & White (1994) - When I go after someth...
# 1                                                  7
# 2                                                  6
# 3                                                  1
# 4                                                  7
#
#                                     BIS/BAS scale_22  \
# 0  Carver & White (1994) - I have very few fears ...
# 1                                                  5
# 2                                                  4
# 3                                                  6
# 4                                                  8
#
#                                     BIS/BAS scale_23  \
# 0  Carver & White (1994) - It would excite me to ...
# 1                                                  6
# 2                                                  4
# 3                                                  4
# 4                                                  7
#
#                                     BIS/BAS scale_24  \
# 0  Carver & White (1994) - I worry about making m...
# 1                                                  6
# 2                                                  7
# 3                                                  8
# 4                                                  8
#
#                          gender  \
# 0  Please indicate your gender.
# 1                             2
# 2                             1
# 3                             2
# 4                             1
#
#                                                  age  \
# 0  Please indicate your age (numerical values only).
# 1                                                 26
# 2                                                 22
# 3                                                 19
# 4                                                 19
#
#                                            education  \
# 0  Please indicate the highest degree you have co...
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#                                                  job              PROLIFIC_PID
# 0  Which of the following best describes your job...              PROLIFIC_PID
# 1                                                  1  5e82332d4fa0db0b3df909ff
# 2                                                  1  5fc26d71c9e79a327ac24f7f
# 3                                                  4  5f53bd22e52c096e869c985e
# 4                                                  1  5f89a35824bee7076b6d536c

# %%
#first column is a repetition of the title, we do not need it 
vc = vc.iloc[1: , :]

# %%
#columns needed for analysis
df1 = vc[['scarcity_6', 'scarcity_9', 'scarcity_7', 'control_1', 'control_2', 'control_3']].copy()

# %%
#combine all scarcity columns into one
df1['combined_scarcity'] = df1['scarcity_6']+' '+df1['scarcity_9']+' '+df1['scarcity_7']

#combine all control columns into one
df1['combined_control'] = df1['control_1']+' '+df1['control_2']+' '+df1['control_3']

# %%
#df_scarcity = df1[['combined_scarcity']]
#df_scarcity

# %%
#df_control = df1[['combined_control']]
#df_control

# %%
result = df1[['combined_scarcity', 'combined_control']]
result
# Out:
#                                      combined_scarcity  \
# 1                                                  NaN
# 2                                                  NaN
# 3    When I had to do work for school. When I had t...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221  When in traffic/public transportation In the b...
#
#                                       combined_control
# 1                                shopping school party
# 2                                     study party rest
# 3                                                  NaN
# 4                    went to school studied programmed
# 5                                  drink smoke had sex
# ..                                                 ...
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220  walked to buy medicine and get pension for my ...
# 221                                                NaN
#
# [221 rows x 2 columns]

# %%
null_values = result[(result['combined_scarcity'].isnull()) & (result['combined_control'].isnull())]
null_values
# Out:
#     combined_scarcity combined_control
# 208               NaN              NaN
# 209               NaN              NaN
# 210               NaN              NaN
# 211               NaN              NaN
# 212               NaN              NaN
# 213               NaN              NaN
# 214               NaN              NaN
# 215               NaN              NaN
# 216               NaN              NaN
# 217               NaN              NaN
# 218               NaN              NaN
# 219               NaN              NaN

# %%
#12 missing values -> fui confirmar ao excel e estes valores não existem
result.drop(result[(result['combined_scarcity'].isnull()) & (result['combined_control'].isnull())].index, inplace=True)
result
# Out:
# C:\Users\Joana Tavares\anaconda3\envs\bi\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                      combined_scarcity  \
# 1                                                  NaN
# 2                                                  NaN
# 3    When I had to do work for school. When I had t...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 205                                                NaN
# 206  When I was at work When I tried to study When ...
# 207  When I had my last exams When I had a lot work...
# 220                                                NaN
# 221  When in traffic/public transportation In the b...
#
#                                       combined_control
# 1                                shopping school party
# 2                                     study party rest
# 3                                                  NaN
# 4                    went to school studied programmed
# 5                                  drink smoke had sex
# ..                                                 ...
# 205  Went to Convento de Cristo Dinned with some ni...
# 206                                                NaN
# 207                                                NaN
# 220  walked to buy medicine and get pension for my ...
# 221                                                NaN
#
# [209 rows x 2 columns]

# %%
#fill NaN values with ''
result['combined_scarcity'] = result['combined_scarcity'].fillna('')
result['combined_control'] = result['combined_control'].fillna('')
# Out:
# C:\Users\JOANAT~1\AppData\Local\Temp/ipykernel_14012/1603878843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['combined_scarcity'] = result['combined_scarcity'].fillna('')
# C:\Users\JOANAT~1\AppData\Local\Temp/ipykernel_14012/1603878843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['combined_control'] = result['combined_control'].fillna('')

# %%
#create our target column
result['target'] = 1*np.array(result['combined_scarcity']!="")

#create sentence column (join combined_scarcity and combined_control together)
result['sentence'] = result['combined_scarcity'] + result['combined_control']
# Out:
# C:\Users\JOANAT~1\AppData\Local\Temp/ipykernel_14012/2478008014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['target'] = 1*np.array(result['combined_scarcity']!="")
# C:\Users\JOANAT~1\AppData\Local\Temp/ipykernel_14012/2478008014.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['sentence'] = result['combined_scarcity'] + result['combined_control']

# %%
df = result.copy()

# %%
#we do not need combined_scarcity and combined_control, since we already joined both in sentence. we can drop those columns
df = df.drop(['combined_scarcity', 'combined_control'], axis=1)
df
# Out:
#      target                                           sentence
# 1         0                              shopping school party
# 2         0                                   study party rest
# 3         1  When I had to do work for school. When I had t...
# 4         0                  went to school studied programmed
# 5         0                                drink smoke had sex
# ..      ...                                                ...
# 205       0  Went to Convento de Cristo Dinned with some ni...
# 206       1  When I was at work When I tried to study When ...
# 207       1  When I had my last exams When I had a lot work...
# 220       0  walked to buy medicine and get pension for my ...
# 221       1  When in traffic/public transportation In the b...
#
# [209 rows x 2 columns]

# %%
#re arrange columns
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df
# Out:
#                                               sentence  target
# 1                                shopping school party       0
# 2                                     study party rest       0
# 3    When I had to do work for school. When I had t...       1
# 4                    went to school studied programmed       0
# 5                                  drink smoke had sex       0
# ..                                                 ...     ...
# 205  Went to Convento de Cristo Dinned with some ni...       0
# 206  When I was at work When I tried to study When ...       1
# 207  When I had my last exams When I had a lot work...       1
# 220  walked to buy medicine and get pension for my ...       0
# 221  When in traffic/public transportation In the b...       1
#
# [209 rows x 2 columns]

# %%
X = df.loc[:, ['sentence']]
y = df.loc[:, ['target']]

# %%
train, test = train_test_split(df, test_size=0.3)

# %% [markdown]
# # Baseline Preprocessing

# %%
stop = text.ENGLISH_STOP_WORDS
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def stem_sentences(sentence):
    tokens = sentence.split()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(stemmed_tokens)

def lemmatize_sentences(sentence):
    tokens = sentence.split()
    lemmd_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmd_tokens)

def basic_preprocessing(df_, col, stop=[]):
    
    df = df_.copy()
    df['original'] = df[col]
    """
    Baseline preprocessing: 
        - lowercase
        - remove symbols (keep letters, ?, !)
        - remove stop words
        - use stemming
    """
    keep = ['?', '!']
    
    ## Lowercase
    df[col] = df[col].str.lower()
    
    ## Remove symbols
    df[col] = df[col].apply(lambda x: ''.join([re.sub(r'[\.;:,\"\'\/]','',x)]))
    
    ## Remove the extra space left before symbols
    ## e.g. "who are you ?" >> "who are you?"
    ## Not sure if this should be done, comment out if not
    ## df[col] = df[col].apply(lambda x: str.replace(x,' ?','?'))
    ## df[col] = df[col].apply(lambda x: str.replace(x,' !','!'))

    
    ## Remove stop words ?
    ## https://towardsdatascience.com/text-pre-processing-stop-words-removal-using-different-libraries-f20bac19929a
    if len(stop) > 0:
        df[col] = df[col].apply(lambda x: ' '.join([word for word in x.split(' ') if word not in (stop)]))
    
    ## Use Stemming
    df[col] = df[col].apply(lambda x: stem_sentences(x) )
    
    ## Remove excess space
    df[col] = df[col].str.strip()
    
    return df


def text_preprocessing(df_, col, stop=[]):
    
    df = df_.copy()
    df['original'] = df[col]
    """
    Baseline preprocessing: 
        - lowercase
        - remove symbols (keep letters, ?, !)
        - remove stop words in pipeline instead of in preprocessing
        - use lemmatizing instead 
    """
    keep = ['?', '!']
    
    ## Lowercase
    df[col] = df[col].str.lower()
    
    ## Remove symbols
    df[col] = df[col].apply(lambda x: ''.join([re.sub(r'[\.;:,\"\'\/]','',x)]))
        
    ## Use Lemmatizer
    df[col] = df[col].apply(lambda x: lemmatize_sentences(x) )
    
    ## Remove excess spaces
    df[col] = df[col].apply(lambda x: re.sub(' +', ' ', x))
    df[col] = df[col].str.strip()
    
    return df

# %%
train_set_prep_basic = basic_preprocessing(train, 'sentence', stop)
train_set_prep = text_preprocessing(train, 'sentence', stop)

# %%
dev_set_prep_basic = basic_preprocessing(test, 'sentence', stop)
dev_set_prep = text_preprocessing(test, 'sentence', stop)

# %% [markdown]
# # Data Understanding

# %%
labels = {
    0: 'control',
    1: 'scarcity'
}

# %%
X_train_basic = train_set_prep_basic['sentence']
Y_train_basic = train_set_prep_basic['target']

X_dev_basic = dev_set_prep_basic['sentence']
Y_dev_basic = dev_set_prep_basic['target']

# %%
X_train = train_set_prep['sentence']
Y_train = train_set_prep['target']

X_dev = dev_set_prep['sentence']
Y_dev = dev_set_prep['target']

# %%
fig, ax = plt.subplots(figsize=(5,5))
y_counts = np.bincount(Y_train)
ax.bar(range(0,2), y_counts)
ax.set(xticks=range(0,2), xlim=[-1, 2])

plt.title("Distribution of Training Data Labels")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
y_counts = np.bincount(Y_dev)
ax.bar(range(0,2), y_counts)
ax.set(xticks=range(0,2), xlim=[-1, 2])

plt.title("Distribution of Test Data Labels")
plt.show()

# %% [markdown]
# # Model Selection

# %%
f1labels = ["F1 " + labels[i] for i in range(len(labels))]
rclabels = ["Recall " + labels[i] for i in range(len(labels))]
pclabels = ["Precision " + labels[i] for i in range(len(labels))]
numlabels = [i for i in range(len(labels))]

# %%
def get_scores(preds, label, cv_score, truth=Y_dev):
    return pd.DataFrame([[label,
               accuracy_score(truth, preds),
               recall_score(truth, preds, average='macro'),
               precision_score(truth, preds, average='macro'),
               f1_score(truth, preds, average='macro', ),
               cv_score,
               *(f1_score(truth, preds, average=None, labels=numlabels)),
               *(recall_score(truth, preds, average=None, labels=numlabels)),
               *(precision_score(truth, preds, average=None, labels=numlabels)),
            ]],
             columns=["Model", "Accuracy", "Recall", "Precision", "F1", "Train Accuracy", *f1labels, *rclabels, *pclabels ],
             index=[label]
        )
    
def print_scores(preds, gs_, Y=Y_dev):
    
    print("Best parameters: ")
    print(gs_.best_params_)
    print("------------------------")

    print("Accuracy:         ", round(accuracy_score(Y_dev, preds),4))
    print("Macro F1:         ", round(f1_score(Y_dev, preds, average='macro'),4))
    print("Macro Recall:     ", round(recall_score(Y_dev, preds, average='macro'),4))
    print("Macro Precision:  ", round(precision_score(Y_dev, preds, average='macro'),4))
    print("Best Train Score: ", round(gs_.best_score_,4))

    return

def plot_cm(preds, title, Y=Y_dev):
    cm_ = confusion_matrix(Y, preds)
    df_cm = pd.DataFrame(cm_, index=numlabels, columns=numlabels)
    
    fig, ax = plt.subplots(figsize=(7,5))
    
    ax = sns.heatmap(df_cm, annot=True,cmap="Blues", fmt="d")
    ax.set_ylabel("True Label")
    ax.set_xlabel("Predicted Label")
    
    plt.title("Confusion Matrix: "+title, fontsize=12)
    
    
    plt.show()
    #fn = './imgs03/ConfusionMatrix_' + title.replace(' ','-') + '.png'
    #fig.savefig(fn, bbox_inches='tight', transparent=True)
    
    return

# %%
score_func = 'accuracy'

# %% [markdown]
# # Baseline KNN

# %%
pipe_knn = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('classifier', KNeighborsClassifier()),  # 
])

## Uses values of default params as grid search values
grid_knn = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
}

gs_knn = GridSearchCV(pipe_knn, grid_knn, n_jobs=-1, cv=10, scoring=score_func)
gs_knn.fit(X_train_basic, Y_train_basic)
gs_knn_pred = gs_knn.predict(X_dev_basic)

# %%
print_scores(gs_knn_pred, gs_knn)
scores = get_scores(gs_knn_pred, "KNN Baseline", gs_knn.best_score_)
plot_cm(gs_knn_pred, "Baseline")
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None}
# ------------------------
# Accuracy:          0.8889
# Macro F1:          0.8831
# Macro Recall:      0.8862
# Macro Precision:   0.8805
# Best Train Score:  0.8562

# %% [markdown]
# ## KNN Optimized

# %%
pipe_knno = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer  
    ('knn', KNeighborsClassifier()),  # 
])

## Uses values of default params as grid search values
grid_knno = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "knn__n_neighbors": [20],
    "knn__metric": ['cosine'],
    
}

gs_knno = GridSearchCV(pipe_knno, grid_knno, n_jobs=-1, cv=10, scoring=score_func)
gs_knno.fit(X_train, Y_train)
gs_knno_pred = gs_knno.predict(X_dev)

# %%
print_scores(gs_knno_pred, gs_knno)
scores = pd.concat([scores,get_scores(gs_knno_pred, "KNN", gs_knno.best_score_)])
plot_cm(gs_knno_pred, "KNN")
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'knn__metric': 'cosine', 'knn__n_neighbors': 20}
# ------------------------
# Accuracy:          0.873
# Macro F1:          0.869
# Macro Recall:      0.8814
# Macro Precision:   0.8643
# Best Train Score:  0.8757

# %% [markdown]
# ## MNB

# %%
pipe_mnb = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('classifier', MultinomialNB()),  # 
])

## Uses values of default params as grid search values
grid_mnb = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "classifier__alpha": [.5]
}

gs_mnb = GridSearchCV(pipe_mnb, grid_mnb, n_jobs=-1, cv=10, scoring=score_func)

gs_mnb.fit(X_train, Y_train)
gs_mnb_pred = gs_mnb.predict(X_dev)

# %%
print_scores(gs_mnb_pred, gs_mnb)
scores = pd.concat([scores,get_scores(gs_mnb_pred, "MultinomialNB", gs_mnb.best_score_)])
plot_cm(gs_knno_pred, "MultinomialNB")
# Out:
# Best parameters:
# {'classifier__alpha': 0.5, 'count__ngram_range': (1, 1), 'count__stop_words': None}
# ------------------------
# Accuracy:          0.8889
# Macro F1:          0.8847
# Macro Recall:      0.8942
# Macro Precision:   0.8796
# Best Train Score:  0.9043

# %% [markdown]
# ## SGD

# %%
pipe_sgd = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('sgd', SGDClassifier(random_state=RANDOM_STATE, max_iter=3000)),
])

grid_sgd = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "sgd__loss": ['log'],    
}

gs_sgd = GridSearchCV(pipe_sgd, grid_sgd, n_jobs=-1, cv=10, scoring=score_func)
gs_sgd.fit(X_train, Y_train)

gs_sgd_pred = gs_sgd.predict(X_dev)

# %%
print_scores(gs_sgd_pred, gs_sgd)
get_scores(gs_sgd_pred, "SGD", gs_sgd.best_score_)
scores = pd.concat([scores,get_scores(gs_sgd_pred, "SGDClassifier", gs_sgd.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'sgd__loss': 'log'}
# ------------------------
# Accuracy:          0.9524
# Macro F1:          0.9491
# Macro Recall:      0.9455
# Macro Precision:   0.9533
# Best Train Score:  0.9181

# %%
plot_cm(gs_sgd_pred, "SGDClassifier")

# %% [markdown]
# ## LR

# %%
pipe_lr = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('lr', LogisticRegression(random_state=RANDOM_STATE, max_iter=2000)),
])

grid_lr = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "lr__solver": ['lbfgs'],
    "lr__multi_class": ['multinomial'],
    #"lr__": [],
}

gs_lr = GridSearchCV(pipe_lr, grid_lr, n_jobs=-1, cv=10, scoring=score_func)

gs_lr.fit(X_train, Y_train)
gs_lr_pred = gs_lr.predict(X_dev)

# %%
print_scores(gs_lr_pred, gs_lr)
get_scores(gs_lr_pred, "LogisticRegression", gs_lr.best_score_)

scores = pd.concat([scores,get_scores(gs_lr_pred, "LogisticRegression", gs_lr.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'lr__multi_class': 'multinomial', 'lr__solver': 'lbfgs'}
# ------------------------
# Accuracy:          0.9206
# Macro F1:          0.9152
# Macro Recall:      0.9119
# Macro Precision:   0.919
# Best Train Score:  0.9319

# %%
plot_cm(gs_lr_pred, "LogisticRegression")

# %% [markdown]
# ## DT

# %%
pipe_dt = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('dt', DecisionTreeClassifier(random_state=RANDOM_STATE)),
])

grid_dt = {
    "count__ngram_range": [(1,1), (2,4)],
    "count__stop_words": ["english", None],
    "dt__criterion": ['gini'],
    #"dt__": [],
    
}

gs_dt = GridSearchCV(pipe_dt, grid_dt, n_jobs=-1, cv=10, scoring=score_func)

gs_dt.fit(X_train, Y_train)
gs_dt_pred = gs_dt.predict(X_dev)

# %%
print_scores(gs_dt_pred, gs_dt)
get_scores(gs_dt_pred, "DecisionTreeClassifier", gs_dt.best_score_)

scores = pd.concat([scores,get_scores(gs_dt_pred, "DecisionTreeClassifier", gs_dt.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'dt__criterion': 'gini'}
# ------------------------
# Accuracy:          0.8254
# Macro F1:          0.8134
# Macro Recall:      0.8109
# Macro Precision:   0.8163
# Best Train Score:  0.7957

# %%
plot_cm(gs_dt_pred, "DecisionTreeClassifier")

# %% [markdown]
# ## GB

# %%
pipe_gb = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('gb', GradientBoostingClassifier(random_state=RANDOM_STATE)),
])

grid_gb = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "gb__loss": ['deviance'],
    "gb__n_estimators": [200],
    "gb__learning_rate": [.25],    
}

gs_gb = GridSearchCV(pipe_gb, grid_gb, n_jobs=-1, cv=10, scoring=score_func)

gs_gb.fit(X_train, Y_train)
gs_gb_pred = gs_gb.predict(X_dev)

# %%
print_scores(gs_gb_pred, gs_gb)
get_scores(gs_gb_pred, "GradientBoostingClassifier", gs_gb.best_score_)

scores = pd.concat([scores,get_scores(gs_gb_pred, "GradientBoostingClassifier", gs_gb.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'gb__learning_rate': 0.25, 'gb__loss': 'deviance', 'gb__n_estimators': 200}
# ------------------------
# Accuracy:          0.8571
# Macro F1:          0.8411
# Macro Recall:      0.8285
# Macro Precision:   0.8678
# Best Train Score:  0.8495

# %%
plot_cm(gs_gb_pred, "GradientBoostingClassifier")

# %% [markdown]
# ## SVM

# %%
pipe_sv = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('svc', SVC(random_state=RANDOM_STATE)),
])

grid_sv = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "svc__kernel": ['linear'],
    "svc__decision_function_shape": ['ovo'],
}

gs_sv = GridSearchCV(pipe_sv, grid_sv, n_jobs=-1, cv=10, scoring=score_func)

gs_sv.fit(X_train, Y_train)
gs_sv_pred = gs_sv.predict(X_dev)

# %%
print_scores(gs_sv_pred, gs_sv)
get_scores(gs_sv_pred, "SVC", gs_sv.best_score_)

scores = pd.concat([scores,get_scores(gs_sv_pred, "SVC", gs_sv.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'svc__decision_function_shape': 'ovo', 'svc__kernel': 'linear'}
# ------------------------
# Accuracy:          0.9206
# Macro F1:          0.9136
# Macro Recall:      0.9038
# Macro Precision:   0.9286
# Best Train Score:  0.9319

# %%
plot_cm(gs_sv_pred, "SVC")

# %% [markdown]
# ## Voting Classifier

# %%
vc_ = VotingClassifier(
    estimators=[('lr', LogisticRegression(max_iter=1000, random_state=RANDOM_STATE)), 
                ('sg', SGDClassifier(random_state=RANDOM_STATE)), 
                ('nb', MultinomialNB()),
                ('gb', GradientBoostingClassifier(random_state=RANDOM_STATE)),
                ('sv', SVC(random_state=RANDOM_STATE))
               ],
    voting='hard'
)

vc_pipe_ = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer    
        ('vc', vc_)
    ])


grid_vc_ = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None]
}

gs_vc_ = GridSearchCV(vc_pipe_, grid_vc_, n_jobs=-1, cv=10, scoring=score_func)

gs_vc_.fit(X_train, Y_train)
gs_vc_pred_ = gs_vc_.predict(X_dev)

# %%
print_scores(gs_vc_pred_, gs_vc_)
get_scores(gs_vc_pred_, "VotingClassifier_NoTuning", gs_vc_.best_score_)

scores = pd.concat([scores,get_scores(gs_vc_pred_, "VotingClassifier_NoTuning", gs_vc_.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None}
# ------------------------
# Accuracy:          0.9206
# Macro F1:          0.9152
# Macro Recall:      0.9119
# Macro Precision:   0.919
# Best Train Score:  0.9186

# %% [markdown]
# ### Using optimized based estimators

# %%
vc = VotingClassifier(
    estimators=[('lr', LogisticRegression(max_iter=1000, random_state=RANDOM_STATE, solver='lbfgs', multi_class='multinomial')), 
                ('sg', SGDClassifier(random_state=RANDOM_STATE, loss='log')), 
                ('nb', MultinomialNB(alpha=.5)),
                ('gb', GradientBoostingClassifier(random_state=RANDOM_STATE, loss='deviance', n_estimators=200, learning_rate=.25)),
                ('sv', SVC(random_state=RANDOM_STATE, kernel='linear', decision_function_shape='ovo'))
               ],
    voting='hard'
)

vc_pipe = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer  
        ('vc', vc)
    ])


grid_vc = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None]
}

gs_vc = GridSearchCV(vc_pipe, grid_vc, n_jobs=-1, cv=10, scoring=score_func)

gs_vc.fit(X_train, Y_train)
gs_vc_pred = gs_vc.predict(X_dev)

# %%
print_scores(gs_vc_pred, gs_vc)
get_scores(gs_vc_pred, "VotingClassifier", gs_vc.best_score_)

scores = pd.concat([scores,get_scores(gs_vc_pred, "VotingClassifier", gs_vc.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None}
# ------------------------
# Accuracy:          0.9365
# Macro F1:          0.9315
# Macro Recall:      0.9247
# Macro Precision:   0.9407
# Best Train Score:  0.9386

# %%
plot_cm(gs_vc_pred, "VotingClassifier")

# %% [markdown]
# ## RF

# %%
pipe_rf = Pipeline([
    ('count', TfidfVectorizer()),     # TfidfVectorizer 
    ('rf', RandomForestClassifier(random_state=RANDOM_STATE)),
])

grid_rf = {
    "count__ngram_range": [(1,1)],
    "count__stop_words": [None],
    "rf__n_estimators": [200],
    "rf__criterion": ['gini'],

}

gs_rf = GridSearchCV(pipe_rf, grid_rf, n_jobs=-1, cv=10, scoring=score_func)

gs_rf.fit(X_train, Y_train)
gs_rf_pred = gs_rf.predict(X_dev)

# %%
print_scores(gs_rf_pred, gs_rf)
get_scores(gs_rf_pred, "RandomForestClassifier", gs_rf.best_score_)

scores = pd.concat([scores,get_scores(gs_rf_pred, "RandomForestClassifier", gs_rf.best_score_)])
# Out:
# Best parameters:
# {'count__ngram_range': (1, 1), 'count__stop_words': None, 'rf__criterion': 'gini', 'rf__n_estimators': 200}
# ------------------------
# Accuracy:          0.8889
# Macro F1:          0.879
# Macro Recall:      0.8702
# Macro Precision:   0.8929
# Best Train Score:  0.891

# %%
plot_cm(gs_rf_pred, "RandomForestClassifier")

# %%
scores.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)
# Out:
#                          Model  Accuracy    Recall  Precision        F1  \
# 0                SGDClassifier  0.952381  0.945513   0.953261  0.949098
# 1             VotingClassifier  0.936508  0.924679   0.940687  0.931522
# 2           LogisticRegression  0.920635  0.911859   0.919022  0.915163
# 3                          SVC  0.920635  0.903846   0.928571  0.913580
# 4    VotingClassifier_NoTuning  0.920635  0.911859   0.919022  0.915163
# 5                 KNN Baseline  0.888889  0.886218   0.880526  0.883117
# 6                MultinomialNB  0.888889  0.894231   0.879630  0.884706
# 7       RandomForestClassifier  0.888889  0.870192   0.892857  0.879012
# 8                          KNN  0.873016  0.881410   0.864286  0.869023
# 9   GradientBoostingClassifier  0.857143  0.828526   0.867823  0.841132
# 10      DecisionTreeClassifier  0.825397  0.810897   0.816304  0.813358
#
#     Train Accuracy  F1 control  F1 scarcity  Recall control  Recall scarcity  \
# 0         0.918095    0.962025     0.936170        0.974359         0.916667
# 1         0.938571    0.950000     0.913043        0.974359         0.875000
# 2         0.931905    0.936709     0.893617        0.948718         0.875000
# 3         0.931905    0.938272     0.888889        0.974359         0.833333
# 4         0.918571    0.936709     0.893617        0.948718         0.875000
# 5         0.856190    0.909091     0.857143        0.897436         0.875000
# 6         0.904286    0.906667     0.862745        0.871795         0.916667
# 7         0.890952    0.913580     0.844444        0.948718         0.791667
# 8         0.875714    0.891892     0.846154        0.846154         0.916667
# 9         0.849524    0.891566     0.790698        0.948718         0.708333
# 10        0.795714    0.860759     0.765957        0.871795         0.750000
#
#     Precision control  Precision scarcity
# 0            0.950000            0.956522
# 1            0.926829            0.954545
# 2            0.925000            0.913043
# 3            0.904762            0.952381
# 4            0.925000            0.913043
# 5            0.921053            0.840000
# 6            0.944444            0.814815
# 7            0.880952            0.904762
# 8            0.942857            0.785714
# 9            0.840909            0.894737
# 10           0.850000            0.782609

# %%
scores.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)\
        .to_csv('scores_tfidfvectorizer.csv', index=False)
